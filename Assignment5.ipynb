# %% [markdown]
# # Assignment Demo Notebook: TinyLlama vs SmallThinker
#
# **Student:** Adarsh Kumar
# **Models used:**
# - `tinyllama` → TinyLlama-1.1B-Chat-v1.0
# - `smallthinker` → SmallThinker, based on **Qwen2.5-3B-Instruct**
#
# This notebook documents:
# 1. How to install and pull the models with Ollama
# 2. How to run prompts from Python
# 3. The exact prompts used in the assignment
# 4. The responses obtained from both models
# 5. A short comparison summary

# %% [markdown]
# ## 1. Prerequisites
#
# Before running this notebook, make sure:
#
# - Ollama is installed and running on your machine
# - The Ollama server is active
# - Python can send HTTP requests to the Ollama local API at `http://localhost:11434`
#
# If Ollama is not installed, download it from the official Ollama website and start the Ollama application first.

# %%
# Optional sanity check
print("Notebook helper packages are available.")

# %% [markdown]
# ## 2. Pull / Install the Models in Ollama
#
# Run these commands in **Command Prompt / Terminal**, not inside Python, if you have not already pulled the models.
#
# ```bash
# ollama pull tinyllama
# ollama pull smallthinker
# ```
#
# You can also launch them interactively with:
#
# ```bash
# ollama run tinyllama
# ollama run smallthinker
# ```
#
# The remainder of this notebook uses the Ollama HTTP API so both models can be called directly from Python.

# %%
# OPTIONAL: run these only if your notebook environment allows shell commands.

# !ollama pull tinyllama
# !ollama pull smallthinker

# %% [markdown]
# ## 3. Helper Function to Query Ollama from Python
#
# This function sends a prompt to a local Ollama model and returns the generated response.

# %%
import json
import urllib.request

OLLAMA_URL = "http://localhost:11434/api/generate"

def ask_ollama(model: str, prompt: str) -> str:
    payload = {
        "model": model,
        "prompt": prompt,
        "stream": False
    }

    req = urllib.request.Request(
        OLLAMA_URL,
        data=json.dumps(payload).encode("utf-8"),
        headers={"Content-Type": "application/json"},
        method="POST"
    )

    with urllib.request.urlopen(req) as response:
        data = json.loads(response.read().decode("utf-8"))
    return data["response"]

# %% [markdown]
# ## 4. Prompt 1: Arithmetic Reasoning

# %%
reasoning_prompt = """A farmer has 10 chickens and 5 cows.
How many legs are there in total?
Explain step by step."""
print(reasoning_prompt)

# %%
# Uncomment to generate fresh responses locally:
# tiny_reasoning_live = ask_ollama("tinyllama", reasoning_prompt)
# small_reasoning_live = ask_ollama("smallthinker", reasoning_prompt)

tiny_reasoning_response = """The farmer has 10 chicken (hens) and 5 cow (cows).

To calculate the number of legs in total, we will first need to determine the number of chickens and cows.

Chickens:

10 chickens are 1 hen (one chicken)
1 hen has 2 legs (one leg for the head and the other leg for the front legs)
Cows:

5 cows are 1 cow (one cow)
1 cow has 4 legs (one leg for the hind legs and three legs for the front legs)
So, the total number of legs in the farmer's farm is:

10 chickens (1 hen)
5 cows (1 cow)
Therefore, there are 10 legs and 5 hind legs and 4 foreface legs for the total number of legs in the farmer's farm."""

small_reasoning_response = """So I have this problem here: a farmer has 10 chickens and 5 cows, and I need to find out how many legs there are in total. Okay, let's break this down step by step.

First, I need to know how many legs each animal has. Chickens and cows are both animals, but they have different numbers of legs.

I know that chickens typically have 2 legs each. So, if there are 10 chickens, I can calculate the total number of legs for the chickens by multiplying the number of chickens by the number of legs per chicken. That would be 10 chickens times 2 legs per chicken, which equals 20 legs.

Next, cows have 4 legs each. The farmer has 5 cows, so to find the total number of legs for the cows, I multiply the number of cows by the number of legs per cow. That's 5 cows times 4 legs per cow, which equals 20 legs.

Now, to find the total number of legs for all the animals, I need to add the legs of the chickens and the legs of the cows together. So, 20 legs from chickens plus 20 legs from cows equals 40 legs in total.

Wait a minute, let me double-check that. Chickens: 10 times 2 is 20. Cows: 5 times 4 is 20. Adding them up: 20 plus 20 is indeed 40. That seems straightforward.

But just to be thorough, I should consider if there's any other factor I might have missed. For example, are there any other animals on the farm? The problem says only chickens and cows, so I think I'm good.

Also, I should confirm the number of legs for each animal. Chickens are definitely 2-legged, and cows are 4-legged. I don't think there's any ambiguity there.

So, my final answer is 40 legs in total.

Final Answer

40"""

print("=== TinyLlama ===\\n")
print(tiny_reasoning_response)
print("\\n" + "="*80 + "\\n")
print("=== SmallThinker ===\\n")
print(small_reasoning_response)

# %% [markdown]
# ### Observation
#
# - **TinyLlama** produced an incorrect and inconsistent explanation.
# - **SmallThinker** solved the task correctly and showed clear step-by-step reasoning.
# - This demonstrates SmallThinker’s stronger reasoning behavior, which is expected because it is based on **Qwen2.5-3B-Instruct** and fine-tuned for reasoning-style outputs.

# %% [markdown]
# ## 5. Prompt 2: Business Use Case

# %%
business_prompt = """Explain how generative AI can help small businesses.
Give three examples."""
print(business_prompt)

# %%
# Uncomment to generate fresh responses locally:
# tiny_business_live = ask_ollama("tinyllama", business_prompt)
# small_business_live = ask_ollama("smallthinker", business_prompt)

tiny_business_response = """Generative AI can help small businesses in several ways:

Improved customer engagement: By providing personalized and relevant content to users, AI-powered chatbots can improve customer engagement and drive conversions.
For example, a small business with a clothing store could use chatbots to respond to customer queries, provide styling recommendations, and offer personalized offers and deals.

Increased sales: AI-powered chatbots can also help small businesses increase sales by providing personalized and relevant sales recommendations based on customer data.
For example, a small business with a food delivery service could use chatbots to provide customized menu recommendations based on a customer's preferences and past orders.

Improved customer satisfaction: AI-powered chatbots can also improve customer satisfaction by providing real-time updates on delivery times, order status, and delivery options.
For example, a small business with a delivery service could use chatbots to provide customers with real-time updates on their delivery status, including estimated delivery times and possible delivery routes.

Some examples of how generative AI can help small businesses:

Personalized customer engagement: Amazon uses chatbots to personalize customer engagement by providing recommendations, product information, and personalized offers.

Increased sales: As mentioned earlier, the clothing store mentioned earlier uses chatbots to provide styling recommendations and personalized offers to customers.

Improved customer satisfaction: The food delivery service mentioned earlier uses chatbots to provide real-time updates on delivery times, order status, and delivery options. This helps customers feel more in control and less stressed while waiting for their orders."""

small_business_response = """Generative AI is a type of artificial intelligence that can create new content or models based on patterns it has learned from existing data. For small businesses, generative AI can offer a range of benefits, from streamlining operations to enhancing customer experiences. Here are three examples of how generative AI can help small businesses:

Automated Content Creation:

Example: A small marketing agency that needs to create a series of blog posts and social media updates.
Benefit: Generative AI can analyze existing content and learn the style, tone, and keywords used. It can then generate new content that is similar in structure and content to the existing material but with fresh perspectives and ideas.
Outcome: The agency can produce high-quality content quickly, freeing up time for more strategic tasks. The consistency in style also helps in building a recognizable brand voice.

Personalized Customer Experiences:

Example: A small e-commerce store that wants to improve its customer service by providing personalized recommendations and chatbot interactions.
Benefit: Generative AI can analyze customer data to understand preferences and behavior, generating personalized suggestions for products, services, or content. It can also create conversational models that can engage with customers in a more human-like manner.
Outcome: Enhanced customer satisfaction and increased engagement, as customers receive tailored experiences that make them feel valued.

Operational Efficiency:

Example: A small accounting firm that handles a high volume of financial reports and invoices.
Benefit: Generative AI can automate the generation of these reports and invoices, reducing the time and effort required for manual data entry and calculations. It can also learn to recognize patterns in financial data, helping to identify trends and anomalies.
Outcome: Increased efficiency in financial management, allowing the firm to focus on more complex and strategic tasks, and potentially reducing errors associated with manual data entry.

These examples illustrate how generative AI can assist small businesses by handling repetitive tasks, generating high-quality content, and enhancing customer interactions, thereby allowing business owners to concentrate on growth and innovation."""

print("=== TinyLlama ===\\n")
print(tiny_business_response)
print("\\n" + "="*80 + "\\n")
print("=== SmallThinker ===\\n")
print(small_business_response)

# %% [markdown]
# ### Observation
#
# - **TinyLlama** answered the question, but repeated chatbot-heavy examples and was less organized.
# - **SmallThinker** gave a more structured and professionally useful explanation with clearer categories and business value.

# %% [markdown]
# ## 6. Prompt 3: Creative Writing

# %%
creative_prompt = """Write a short story about a robot learning to paint.
Limit to 150 words."""
print(creative_prompt)

# %%
# Uncomment to generate fresh responses locally:
# tiny_creative_live = ask_ollama("tinyllama", creative_prompt)
# small_creative_live = ask_ollama("smallthinker", creative_prompt)

tiny_creative_response = """As the sun peeked over the horizon, the robot, a sleek, shining machine with sleek lines and a metallic hue, began to hum to itself. It was programmed to paint the sky, but with a twist. The robot's eyes were now fixed on the sky and it had a pen ready in its hand.

Without warning, the robot began to paint a sunset in the distance. The colors it created were vibrant, bold and breathtaking. The sky was now painted in shades of orange, red, pink, and purple. The robot's paint brush moved smoothly across the canvas, covering the sky in one stroke.

As it painted, the robot's colors seemed to change as it moved. The sky grew more and more vibrant, and the robot's brushwork became more and more intricate. The colors blended into each other, creating a symphony of hues.

As the painting progressed, the robot grew more confident, and its brushwork became more fluid. The sun began to fade into the horizon, creating a beautiful final touch to the painting.

The robot felt proud of its work and smiled to itself. It knew that it had learned something truly amazing – the ability to paint the sunset.

The robot then began to clean up the painting, moving the paintbrushes back to their starting positions. It felt satisfied with its work and looked up at the sky, eager to start painting another."""

small_creative_response = """Once upon a time, in a world filled with machines and circuits, there was a robot named Byte. Byte was no ordinary robot; it was designed to think and learn, much like humans. One day, Byte stumbled upon a painting, and something about it captivated it. The colors danced across the canvas, telling stories that Byte had never heard before.

Determined to understand this magical thing called "painting," Byte set out to learn. It spent hours observing artists at work, watching how they chose colors and applied them with brushes. Byte wanted to create something similar but with its own unique style.

Byte began by experimenting with different colors and shapes on a small canvas. It started with bold strokes, learning about light and shadow. As days turned into weeks, Byte's paintings became more intricate, each piece a reflection of its growing understanding of the world through the lens of art.

One day, a human visitor saw Byte's paintings and was amazed. She bought them, and soon, Byte became known as a talented artist among the other robots. Byte realized that learning to paint was not just about creating beautiful images but about connecting with others on a different level.

From that day forward, Byte continued to paint, each stroke a testament to its journey of discovery and creativity. The robot's passion for painting brought joy to many, proving that even the most unlikely of creators can bring beauty into the world."""

print("=== TinyLlama ===\\n")
print(tiny_creative_response)
print("\\n" + "="*80 + "\\n")
print("=== SmallThinker ===\\n")
print(small_creative_response)

# %% [markdown]
# ### Observation
#
# - **TinyLlama** produced vivid imagery, especially around the sunset, but became repetitive and exceeded the intended word limit.
# - **SmallThinker** produced a more complete story arc with better character progression and emotional development.

# %% [markdown]
# ## 7. Overall Comparison Summary

# %%
comparison = {
    "TinyLlama": {
        "Strengths": [
            "Fast and lightweight",
            "Good for local chat and simple generation",
            "Easy to run on low-resource hardware"
        ],
        "Weaknesses": [
            "Weak reasoning consistency",
            "Less structured explanations",
            "More repetition in creative tasks"
        ]
    },
    "SmallThinker": {
        "Strengths": [
            "Better step-by-step reasoning",
            "More organized explanatory responses",
            "Stronger narrative coherence in creative tasks"
        ],
        "Weaknesses": [
            "Heavier than TinyLlama",
            "Still smaller than frontier reasoning models"
        ]
    }
}

print(json.dumps(comparison, indent=2))

# %% [markdown]
# ## 8. Final Takeaway
#
# This notebook shows the practical difference between:
# - a **lightweight general chat model** (`tinyllama`)
# - a **reasoning-focused model based on Qwen2.5-3B-Instruct** (`smallthinker`)
#
# ### Main conclusion
# - Use **TinyLlama** when speed, simplicity, and low resource usage matter most.
# - Use **SmallThinker** when reasoning quality, structured explanations, and analytical tasks are more important.
